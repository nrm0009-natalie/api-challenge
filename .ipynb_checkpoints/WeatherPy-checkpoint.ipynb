# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from citipy import citipy
import os
import csv
plt.rcParams["figure.figsize"] = [10, 5]

# Import API key
from api_keys import api_key


# Output File (CSV)
output_data_file = os.path.join("/Users/admin/Documents/Data_Analytics_Class/api-challenge/weather.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1700)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1700)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="

#query_url = url + "appid=" + api_key + "&units=" + units + "&q="

#printing out an example (Paris) to get keys
weather = requests.get(query_url + "Vienna").json()
print(json.dumps(weather, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 48.21,
#         "lon": 16.37
#     },
#     "dt": 1571522823,
#     "id": 2761369,
#     "main": {
#         "humidity": 93,
#         "pressure": 1014,
#         "temp": 51.67,
#         "temp_max": 53.01,
#         "temp_min": 50
#     },
#     "name": "Vienna",
#     "sys": {
#         "country": "AT",
#         "id": 6878,
#         "message": 0.0092,
#         "sunrise": 1571548836,
#         "sunset": 1571587071,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 4100,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         },
#         {
#             "description": "fog",
#             "icon": "50n",
#             "id": 741,
#             "main": "Fog"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 3.36
#     }
# }

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_number = []
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities:
    try:
        weather_data = requests.get(query_url + city).json()
        city_name.append(weather_data["name"])
        cloudiness.append(weather_data["clouds"]["all"])
        country.append(weather_data["sys"]["country"])
        date.append(weather_data["dt"])
        humidity.append(weather_data["main"]["humidity"])
        lat.append(weather_data["coord"]["lat"])
        lng.append(weather_data["coord"]["lon"])
        max_temp.append(weather_data["main"]["temp_max"])
        wind_speed.append(weather_data["wind"]["speed"])
        print("City number " + city_name.index(city) + " | " + weather_data["name"])
    except:
        print("City not found. Skipping...")
    time.sleep(1.5)
    #city_number.append(index)
# Out:
# City not found. Skipping...
# Rikitea
# Punta Arenas
# Tateyama
# Vaini
# Norman Wells
# Hofn
# Albany
# Erenhot
# Saskylakh
# Ozark
# Port Hedland
# Otjiwarongo
# Hasaki
# Port Elizabeth
# Busselton
# City not found. Skipping...
# Yuanping
# Lompoc
# Tasiilaq
# Santona
# Puerto Ayora
# Rundu
# Weyburn
# Narsaq
# Port Lincoln
# Bethel
# Green River
# Carnarvon
# Port Hardy
# Kapaa
# Isangel
# Salalah
# Port Alfred
# Walvis Bay
# Preobrazheniye
# City not found. Skipping...
# Mataura
# Hermanus
# Dikson
# Tanhacu
# City not found. Skipping...
# Sabinas Hidalgo
# Mahebourg
# Victoria
# Yellowknife
# City not found. Skipping...
# Tambovka
# Upernavik
# Avarua
# Kruisfontein
# La Ronge
# Hamilton
# New Norfolk
# Novopavlovka
# Leningradskiy
# Priargunsk
# Ushuaia
# Tuktoyaktuk
# Chokurdakh
# Douglas
# Drayton Valley
# Ballina
# Pak Phanang
# Sokolo
# Kosh-Agach
# Sarangani
# Tevaitoa
# Kedrovyy
# Najran
# City not found. Skipping...
# Bontang
# Beterou
# Praia da Vitoria
# Juneau
# Salinopolis
# Tacuati
# Nortelandia
# Rome
# Whyalla
# Sambava
# La Orilla
# Yanam
# Agadir
# Belmonte
# Bemidji
# Yulara
# City not found. Skipping...
# Galich
# Atherton
# City not found. Skipping...
# Kosonsoy
# Verkhnyaya Inta
# Tera
# Pendleton
# Scarborough
# City not found. Skipping...
# Garissa
# Aklavik
# Jinxiang
# Turayf
# Gorontalo
# Manga
# Kozhva
# Mestia
# Big Bend
# Santa Rosa
# Gataia
# Corovode
# Saint-Joseph
# Boguchany
# City not found. Skipping...
# Henties Bay
# Chapais
# City not found. Skipping...
# Yar-Sale
# City not found. Skipping...
# Sioux Lookout
# City not found. Skipping...
# Saravan
# City not found. Skipping...
# Nioro
# Shenjiamen
# Toplet
# Dubbo
# Martapura
# Seoul
# Araouane
# Nacogdoches
# Mtimbira
# Creston
# City not found. Skipping...
# City not found. Skipping...
# Aksu
# Litovko
# Novyy Oskol
# Odder
# Dunedin
# Astoria
# City not found. Skipping...
# Milkovo
# Sicamous
# Paka
# Moses Lake
# Kargasok
# Atbasar
# Hit
# Mitsamiouli
# Sinnamary
# Cajamarca
# Srikakulam
# City not found. Skipping...
# Sosnovka
# Nichinan
# Asyut
# Uarini
# Zhigansk
# Kichmengskiy Gorodok
# City not found. Skipping...
# Alamogordo
# Ambulu
# City not found. Skipping...
# Akdagmadeni
# Bella Union
# Sidi Ali
# Tonkino
# Narok
# Gurkovo
# Ahvaz
# Hirara
# Nouakchott
# Alassio
# Boende
# Taltal
# Cartagena
# Gillette
# Derzhavinsk
# Namibe
# Charters Towers
# Chulman
# La Rioja
# Gediz
# Qaqortoq
# Agapovka
# Aleksandrov Gay
# Steamboat Springs
# Grand Gaube
# City not found. Skipping...
# Robe
# Telciu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#zipped_data = zip(city_name, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed)
#with open(output_data_file, "w", newline="") as datafile:
 #   writer = csv.writer(datafile)
  #  writer.writerow(["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Long","Max Temp","Wind Speed"])
   # writer.writerows(zipped_data)

# %%
zipped_data = zip(city_name, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed)
weather_df = pd.DataFrame(zipped_data)

    
#view dataframe
weather_df.head()
# Out:
#               0   1   2           3    4      5       6      7      8
# 0       Rikitea  94  PF  1571522824   74 -23.12 -134.97  68.39  21.45
# 1  Punta Arenas   0  CL  1571522826   44 -53.16  -70.91  57.20  12.75
# 2      Tateyama  75  JP  1571522828  100  36.66  137.31  63.00   2.24
# 3         Vaini  87  IN  1571522830   93  15.34   74.49  73.09   2.35
# 4  Norman Wells  75  CA  1571522831   92  65.28 -126.83  30.20   3.36

# %%
city_weather_df = weather_df.rename(columns={0:"City",1:"Cloudiness",2:"Country",3:"Date",4:"Humidity",
                                            5:"Latitude",6:"Longitude", 7:"Max Temp", 8:"Wind Speed"})

#create csv
with open(output_data_file, "w", newline="") as datafile:
    writer = csv.writer(datafile)
    writer.writerows(city_weather_df)
    
city_weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0       Rikitea          94      PF  1571522824        74    -23.12
# 1  Punta Arenas           0      CL  1571522826        44    -53.16
# 2      Tateyama          75      JP  1571522828       100     36.66
# 3         Vaini          87      IN  1571522830        93     15.34
# 4  Norman Wells          75      CA  1571522831        92     65.28
#
#    Longitude  Max Temp  Wind Speed
# 0    -134.97     68.39       21.45
# 1     -70.91     57.20       12.75
# 2     137.31     63.00        2.24
# 3      74.49     73.09        2.35
# 4    -126.83     30.20        3.36

# %%
city_weather_df.count()
# Out:
# City          659
# Cloudiness    659
# Country       659
# Date          659
# Humidity      659
# Latitude      659
# Longitude     659
# Max Temp      659
# Wind Speed    659
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = np.arange(-60,80,0.2124431)
temps = city_weather_df["Max Temp"]
plt.scatter(x_axis, temps, marker="o", facecolors="green", edgecolors="black")
#plt.ylim(35,70)
#plt.xlim(-5,50)
ticks = [-60, -40, -20, 0, 20, 40, 60, 80]
xticks = [value for value in ticks]
plt.xticks(xticks)
plt.title("City Latitude vs. Max Temp on Current Date")
plt.xlabel("Latitude")
plt.ylabel("Max Temp in F")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = np.arange(-60,80,0.2124431)
humidity = city_weather_df["Humidity"]
plt.scatter(x_axis, humidity, marker="o", facecolors="red", edgecolors="black")
#plt.ylim(35,70)
#plt.xlim(-5,50)
ticks = [-60, -40, -20, 0, 20, 40, 60, 80]
xticks = [value for value in ticks]
plt.xticks(xticks)
plt.title("City Latitude vs. Humidity on Current Date")
plt.xlabel("Latitude")
plt.ylabel("% Humidity")
plt.ylim(0,110)
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = np.arange(-60,80,0.2124431)
clouds = city_weather_df["Cloudiness"]
plt.scatter(x_axis, clouds, marker="o", facecolors="blue", edgecolors="black")
#plt.ylim(35,70)
#plt.xlim(-5,50)
ticks = [-60, -40, -20, 0, 20, 40, 60, 80]
xticks = [value for value in ticks]
plt.xticks(xticks)
plt.title("City Latitude vs. Cloudiness on Current Date")
plt.xlabel("Latitude")
plt.ylabel("% Cloudiness")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = np.arange(-60,80,0.2124431)
wind = city_weather_df["Wind Speed"]
plt.scatter(x_axis, wind, marker="o", facecolors="pink", edgecolors="black")
ticks = [-60, -40, -20, 0, 20, 40, 60, 80]
xticks = [value for value in ticks]
plt.xticks(xticks)
#plt.ylim(35,70)
#plt.xlim(-5,50)
plt.title("City Latitude vs. Wind Speed on Current Date")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed in MPH")
plt.grid()
plt.show()
